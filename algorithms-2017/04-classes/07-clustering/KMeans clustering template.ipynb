# %% [markdown]
# # KMeans clustering ANY documents

# %% [markdown]
# ## Read in your files if they're all separate

# %%
import pandas as pd
import glob

filenames = glob.glob("fanfiction-harry-potter/*.txt")

# Maybe use open(filename, encoding='latin-1').read()
# if you're running into trouble
contents = [open(filename, encoding='latin-1').read() for filename in filenames]

df = pd.DataFrame({
    'text': contents,
    'filenames': filenames
})
df.head()
# Out:
#                               filenames  \
# 0  fanfiction-harry-potter/10001898.txt
# 1  fanfiction-harry-potter/10004131.txt
# 2  fanfiction-harry-potter/10004927.txt
# 3  fanfiction-harry-potter/10007980.txt
# 4  fanfiction-harry-potter/10010343.txt
#
#                                                 text
# 0  Prologue: The MissionDisclaimer: All character...
# 1  BlackDisclaimer: I do not own Harry PotterAuth...
# 2  Chapter 1"I'm pregnant.""""Mum please say some...
# 3  Author's Note: Hey, just so you know, this is ...
# 4  Disclaimer: I do not own Harry Potter and frie...

# %% [markdown]
# ## Or read in your CSV with the text column if not

# %%
# import pandas as pd
# df = pd.read_csv("WHAT IS THE FILE???")

# %% [markdown]
# ## Vectorize your documents
#
# What are the options when creating a `TfidfVectorizer`?

# %%
TfidfVectorizer?

# %% [markdown]
# Let's think about:
#
# * **ngram_range**: Do we just want single words? Or more? `(1,2)` is one- and two-word phrases, etc.
# * **max_features**: Can it make things faster? `1` and up
# * **max_df**: Should we ignore words that show up too often? `0.0`-`1.0` for percent, OR an integer for absolute document counts
# * **min_df**: Should we ignore words that show up too little? `0.0`-`1.0` for percent, OR an integer for absolute document counts
# * **vocabulary**: Only care about certain words
#
# Also... how many documents do we have?

# %%
df.shape
# Out:
# (1874, 2)

# %%
# %%time
from sklearn.feature_extraction.text import TfidfVectorizer
from textblob import TextBlob


def textblob_tokenizer(str_input):
    blob = TextBlob(str_input.lower())
    tokens = blob.words
    words = [token.stem() for token in tokens]
    return words

# CUSTOM STOPWORDS
# FIRST, create a list of custom stopwords
from sklearn.feature_extraction import stop_words
custom_stopwords = ['just', 'said', 'love'] + list(stop_words.ENGLISH_STOP_WORDS)

# CUSTOM STOPWORDS
# THEN, instead of stop_words='english'
# add your custom stopwords into the vectorizer
vec = TfidfVectorizer(stop_words=custom_stopwords,
                      max_df=0.9, # If you're in >90%, ignore
                      min_df=0.15, # If you're only in 15%, ignore
                      max_features=250,
                      use_idf=True)

# Fit from the 'text' column of our dataframe
matrix = vec.fit_transform(df['text'])

# Then turn it into a new dataframe
results = pd.DataFrame(matrix.toarray(), columns=vec.get_feature_names())
# Out:
# CPU times: user 4.2 s, sys: 85.9 ms, total: 4.28 s
# Wall time: 4.4 s

# %%
results.head()
# Out:
#        able  actually     albus       arm      arms       ask     asked  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.058290
# 1  0.007969  0.015810  0.021035  0.000000  0.015247  0.008246  0.034870
# 2  0.000000  0.030736  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.009575  0.000000  0.012638  0.019594  0.009161  0.039633  0.034917
# 4  0.023051  0.000000  0.000000  0.047170  0.022052  0.000000  0.050434
#
#        away       bad       bed    ...          won     words      work  \
# 0  0.000000  0.000000  0.000000    ...     0.026641  0.000000  0.000000
# 1  0.054080  0.000000  0.014964    ...     0.000000  0.068611  0.007508
# 2  0.000000  0.000000  0.029091    ...     0.123930  0.000000  0.029191
# 3  0.006498  0.009812  0.000000    ...     0.000000  0.009161  0.009022
# 4  0.078219  0.023620  0.000000    ...     0.000000  0.022052  0.000000
#
#       world    wouldn      yeah      year     years       yes     young
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.021998  0.161977
# 1  0.000000  0.021064  0.000000  0.028493  0.036743  0.032899  0.088822
# 2  0.000000  0.027299  0.000000  0.044313  0.000000  0.025583  0.094186
# 3  0.000000  0.000000  0.043148  0.102715  0.066227  0.039532  0.058217
# 4  0.060497  0.000000  0.000000  0.049454  0.053143  0.038067  0.256938
#
# [5 rows x 250 columns]

# %% [markdown]
# > ...Try it without the TextBlob tokenizer

# %% [markdown]
# ## Cluster your documents

# %%
# %%time
from sklearn.cluster import KMeans

# How many clusters?
number_of_clusters=2
km = KMeans(n_clusters=number_of_clusters)

print("Fitting", number_of_clusters, "clusters usinga ", matrix.shape, "matrix")

# Let's fit it!
km.fit(matrix)
km.fit
# Out:
# Fitting 2 clusters usinga  (1874, 250) matrix
# CPU times: user 18.5 s, sys: 148 ms, total: 18.7 s
# Wall time: 19.3 s

# %% [markdown]
# ## See what they look like

# %%
print("Top terms per cluster:")
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
terms = vec.get_feature_names()
for i in range(number_of_clusters):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :5]]
    print("Cluster {}: {}".format(i, ' '.join(top_ten_words)))
# Out:
# Top terms per cluster:
# Cluster 0: james lily said just like
# Cluster 1: harry hermione ron draco said

# %% [markdown]
# ## Push the category back to the original dataframe

# %%
df['category'] = km.labels_
df
# Out:
#                                  filenames  \
# 0     fanfiction-harry-potter/10001898.txt
# 1     fanfiction-harry-potter/10004131.txt
# 2     fanfiction-harry-potter/10004927.txt
# 3     fanfiction-harry-potter/10007980.txt
# 4     fanfiction-harry-potter/10010343.txt
# 5     fanfiction-harry-potter/10017757.txt
# 6     fanfiction-harry-potter/10018490.txt
# 7     fanfiction-harry-potter/10018889.txt
# 8     fanfiction-harry-potter/10019142.txt
# 9     fanfiction-harry-potter/10019987.txt
# 10    fanfiction-harry-potter/10021604.txt
# 11    fanfiction-harry-potter/10023278.txt
# 12    fanfiction-harry-potter/10023376.txt
# 13    fanfiction-harry-potter/10026221.txt
# 14    fanfiction-harry-potter/10035136.txt
# 15    fanfiction-harry-potter/10036003.txt
# 16    fanfiction-harry-potter/10037071.txt
# 17    fanfiction-harry-potter/10038079.txt
# 18    fanfiction-harry-potter/10038493.txt
# 19    fanfiction-harry-potter/10041730.txt
# 20    fanfiction-harry-potter/10043489.txt
# 21    fanfiction-harry-potter/10043782.txt
# 22    fanfiction-harry-potter/10045762.txt
# 23    fanfiction-harry-potter/10049288.txt
# 24    fanfiction-harry-potter/10050162.txt
# 25    fanfiction-harry-potter/10051779.txt
# 26    fanfiction-harry-potter/10052973.txt
# 27    fanfiction-harry-potter/10053360.txt
# 28    fanfiction-harry-potter/10055985.txt
# 29    fanfiction-harry-potter/10060250.txt
# ...                                    ...
# 1844   fanfiction-harry-potter/9920715.txt
# 1845   fanfiction-harry-potter/9925672.txt
# 1846   fanfiction-harry-potter/9930431.txt
# 1847   fanfiction-harry-potter/9933106.txt
# 1848   fanfiction-harry-potter/9933135.txt
# 1849   fanfiction-harry-potter/9940060.txt
# 1850   fanfiction-harry-potter/9942637.txt
# 1851   fanfiction-harry-potter/9944070.txt
# 1852   fanfiction-harry-potter/9944110.txt
# 1853   fanfiction-harry-potter/9944611.txt
# 1854   fanfiction-harry-potter/9944886.txt
# 1855   fanfiction-harry-potter/9944944.txt
# 1856   fanfiction-harry-potter/9945192.txt
# 1857   fanfiction-harry-potter/9946564.txt
# 1858   fanfiction-harry-potter/9953756.txt
# 1859   fanfiction-harry-potter/9954472.txt
# 1860   fanfiction-harry-potter/9957949.txt
# 1861   fanfiction-harry-potter/9964545.txt
# 1862   fanfiction-harry-potter/9966340.txt
# 1863   fanfiction-harry-potter/9969981.txt
# 1864   fanfiction-harry-potter/9973627.txt
# 1865   fanfiction-harry-potter/9975438.txt
# 1866   fanfiction-harry-potter/9978757.txt
# 1867   fanfiction-harry-potter/9981541.txt
# 1868   fanfiction-harry-potter/9981980.txt
# 1869   fanfiction-harry-potter/9984427.txt
# 1870   fanfiction-harry-potter/9985697.txt
# 1871   fanfiction-harry-potter/9988645.txt
# 1872   fanfiction-harry-potter/9992917.txt
# 1873   fanfiction-harry-potter/9993970.txt
#
#                                                    text  category
# 0     Prologue: The MissionDisclaimer: All character...         0
# 1     BlackDisclaimer: I do not own Harry PotterAuth...         0
# 2     Chapter 1"I'm pregnant.""""Mum please say some...         0
# 3     Author's Note: Hey, just so you know, this is ...         1
# 4     Disclaimer: I do not own Harry Potter and frie...         0
# 5     Disclaimer: I don't own any character in the H...         0
# 6     DISCLAIMER: I don't own Harry Potter and its c...         0
# 7     Katherine Rose-TylerChapter One: the Introduct...         0
# 8     I am no longer that shy little boy anymore.I w...         0
# 9     Happy New year! *throws confetti*I've really b...         0
# 10    2014"It's ridiculous." The red-headed boy shoo...         1
# 11    Disclaimer: Did you really think I was J.K. Ro...         0
# 12    This is my first story on fanfic and I'm nervo...         0
# 13    DISCLAIMER: I don't own anything here that loo...         0
# 14    A/N: So, this is my second ongoing story, and ...         0
# 15    Disclaimer: I do not own Harry Potter. Enjoy t...         0
# 16    For my friend, constant cheerleader and talent...         0
# 17    Disclaimer: Harry Potter's not mineA/N:Another...         0
# 18    Lily Potter was quite happy. Her favourite bro...         0
# 19    A/N: This story follows all of canon besides f...         1
# 20    It's 8th year at Hogwarts. Voldemort is dead. ...         1
# 21    Hey everybody this is my first fic and will en...         0
# 22    Prologue: The Puzzle That Wasn't Meant To Be S...         1
# 23    Prologue REWRITTENA/N: This is a rewritten ver...         0
# 24    I stood at the top of the Astronomy Tower thin...         1
# 25    Title: Twin Dragon Heartstring Cores.Author: L...         1
# 26    Chapter 1Walking down the corridor to potions,...         1
# 27    These characters belong to J.K. Rowling, not m...         0
# 28    A/N: Everyone needs their own version of a Sly...         0
# 29    June 20th, 1992This was it. Dumbledore was sur...         0
# ...                                                 ...       ...
# 1844  Summary: Gryffindor isn't what Slytherin sees ...         0
# 1845  Okay. Lumox. The title will be explained much ...         0
# 1846  Normal Pov(A/N: Story takes place in Harry Pot...         1
# 1847  (A/N: Rated M for mature content and language....         1
# 1848  Hey you guys, I'm back!I wasn't planning on wr...         1
# 1849  Truly, Madly, Deeply, Crazily In Love#Chapter ...         0
# 1850  She took a deep breath as she lay in her hospi...         0
# 1851  Chapter 1Beta Read by optimisticrealist72Thoug...         1
# 1852  "Now begin", Dumbledore's voice boomed over th...         1
# 1853  Hermione's POVShe grabbed another handful of r...         1
# 1854  I thought it would be fun to make one of these...         0
# 1855  Harry`s POVHarry Potter, boy who lived, chosen...         1
# 1856  Okay, so I've been wanting to write a George/H...         0
# 1857  A/N: Adopted from unwrittenlegacy. This will h...         1
# 1858  . . . Sorry . . . Introduction . . . Not the F...         0
# 1859  "Why are we doing this again," Sirius asks gro...         0
# 1860  I do not own any of the characters. You may ho...         1
# 1861  Harry Potter, the Boy-Who-Lived, had always be...         1
# 1862  Original Title: Dipping into the Dark SideOrig...         0
# 1863  A/N: So I woke up the other day with this idea...         0
# 1864  Author's Notes: In my own, happy little world,...         1
# 1865  Title: Fighting For TomorrowRating: TSummary: ...         1
# 1866  Bella Luna, beautiful moon. She wondered if he...         0
# 1867  Authors note: Welcome to all the lovely reader...         1
# 1868  AUTHOR'S NOTEHi everybody! This is my first fa...         0
# 1869  I do not own Harry Potter and I only write for...         1
# 1870  Hi everybody!Im so happy you clicked on this s...         0
# 1871  I fell in love with this pairing and never loo...         0
# 1872  Prologue: A Surrey StartEaster Saturday was pl...         0
# 1873  "Okay, who's going first?" someone shouted ove...         0
#
# [1874 rows x 3 columns]

# %% [markdown]
# ## Be pleased

# %%
df[df.category == 1]
# Out:
#                                  filenames  \
# 3     fanfiction-harry-potter/10007980.txt
# 10    fanfiction-harry-potter/10021604.txt
# 19    fanfiction-harry-potter/10041730.txt
# 20    fanfiction-harry-potter/10043489.txt
# 22    fanfiction-harry-potter/10045762.txt
# 24    fanfiction-harry-potter/10050162.txt
# 25    fanfiction-harry-potter/10051779.txt
# 26    fanfiction-harry-potter/10052973.txt
# 30    fanfiction-harry-potter/10061747.txt
# 31    fanfiction-harry-potter/10061794.txt
# 34    fanfiction-harry-potter/10070079.txt
# 35    fanfiction-harry-potter/10073299.txt
# 39    fanfiction-harry-potter/10084022.txt
# 42    fanfiction-harry-potter/10086764.txt
# 44    fanfiction-harry-potter/10090975.txt
# 45    fanfiction-harry-potter/10092644.txt
# 51    fanfiction-harry-potter/10097915.txt
# 53    fanfiction-harry-potter/10098087.txt
# 58    fanfiction-harry-potter/10107723.txt
# 59    fanfiction-harry-potter/10108027.txt
# 60    fanfiction-harry-potter/10114060.txt
# 61    fanfiction-harry-potter/10114197.txt
# 62    fanfiction-harry-potter/10114274.txt
# 67    fanfiction-harry-potter/10124094.txt
# 71    fanfiction-harry-potter/10127234.txt
# 72    fanfiction-harry-potter/10127513.txt
# 75    fanfiction-harry-potter/10134610.txt
# 77    fanfiction-harry-potter/10135379.txt
# 82    fanfiction-harry-potter/10138430.txt
# 85    fanfiction-harry-potter/10142612.txt
# ...                                    ...
# 1805   fanfiction-harry-potter/9797364.txt
# 1806   fanfiction-harry-potter/9798300.txt
# 1813   fanfiction-harry-potter/9831689.txt
# 1814   fanfiction-harry-potter/9833380.txt
# 1815   fanfiction-harry-potter/9835824.txt
# 1818   fanfiction-harry-potter/9839017.txt
# 1820   fanfiction-harry-potter/9844547.txt
# 1821   fanfiction-harry-potter/9850472.txt
# 1825   fanfiction-harry-potter/9861833.txt
# 1826   fanfiction-harry-potter/9863146.txt
# 1828   fanfiction-harry-potter/9873356.txt
# 1832   fanfiction-harry-potter/9880268.txt
# 1836   fanfiction-harry-potter/9886437.txt
# 1837   fanfiction-harry-potter/9887402.txt
# 1838   fanfiction-harry-potter/9887587.txt
# 1842   fanfiction-harry-potter/9912956.txt
# 1846   fanfiction-harry-potter/9930431.txt
# 1847   fanfiction-harry-potter/9933106.txt
# 1848   fanfiction-harry-potter/9933135.txt
# 1851   fanfiction-harry-potter/9944070.txt
# 1852   fanfiction-harry-potter/9944110.txt
# 1853   fanfiction-harry-potter/9944611.txt
# 1855   fanfiction-harry-potter/9944944.txt
# 1857   fanfiction-harry-potter/9946564.txt
# 1860   fanfiction-harry-potter/9957949.txt
# 1861   fanfiction-harry-potter/9964545.txt
# 1864   fanfiction-harry-potter/9973627.txt
# 1865   fanfiction-harry-potter/9975438.txt
# 1867   fanfiction-harry-potter/9981541.txt
# 1869   fanfiction-harry-potter/9984427.txt
#
#                                                    text  category
# 3     Author's Note: Hey, just so you know, this is ...         1
# 10    2014"It's ridiculous." The red-headed boy shoo...         1
# 19    A/N: This story follows all of canon besides f...         1
# 20    It's 8th year at Hogwarts. Voldemort is dead. ...         1
# 22    Prologue: The Puzzle That Wasn't Meant To Be S...         1
# 24    I stood at the top of the Astronomy Tower thin...         1
# 25    Title: Twin Dragon Heartstring Cores.Author: L...         1
# 26    Chapter 1Walking down the corridor to potions,...         1
# 30    The air whistles and blows through chestnut lo...         1
# 31    Yay! Okay, now to clear this up. Story takes p...         1
# 34    Disclaimer: JK Rowling owns Harry Potter, and ...         1
# 35    Harry Potter And The Unexpected Second LifeAut...         1
# 39    Ginny sat and thought, she didn't do much else...         1
# 42    A/N: This is the second story I've ever writte...         1
# 44    Sunlight poured through her eyelids, a dull re...         1
# 45    It's over. The War. The death. The hurt. Every...         1
# 51    Me: Hello everyone, how are you guys doing? It...         1
# 53    Heyy! I've decided to write a Harry/Ginny fic,...         1
# 58    LLL- Hi guyeseses. New Harry Potter story insp...         1
# 59    Author's notes: Ta-dahhhh! After many years of...         1
# 60    Author's Note: I was suddenly hit with a HP/LV...         1
# 61    A/N Ok, so this is my first FanFic. I think I ...         1
# 62     Disclaimer: Harry Potter and all characters b...         1
# 67    PrologueThe nightmares were back.At first, it ...         1
# 71    I do not own Harry Potter only the idea of thi...         1
# 72    Hey, this is the final multi chapter part to t...         1
# 75    AN: Not JK Rowling wish I was but I'm notI was...         1
# 77    SWITCHA/N: Okay, so this is a new idea that at...         1
# 82    Harry Dursley - Something's Wrong.Lets get the...         1
# 85    A/N this is a Harry Potter fan fic based on th...         1
# ...                                                 ...       ...
# 1805  It was happening again. Night after night, she...         1
# 1806  Alright, this is a rewrite of my fic 'I Can't ...         1
# 1813  A/N: New story time! Yay!There are no propheci...         1
# 1814  Sticky SituationA/N: Hollla! New story for y'a...         1
# 1815  Warning this fic:- contains no slash/yaoi what...         1
# 1818  Summary: Harry was left at the mercies of the ...         1
# 1820  A/N: So this is my first story I've ever poste...         1
# 1821  CHAPTER 1- MAKE NEW FRIENDS BUT KEEP THE OLD.A...         1
# 1825  Title: BodyswitchDisclaimer: This story is bas...         1
# 1826  Disclaimer: Harry Potter is owned by JK Rowlin...         1
# 1828  A/N: A few months ago, I read an article on Mu...         1
# 1832  Chapter one: Potions Masters ApprenticeIt was ...         1
# 1836  Author's note: To anyone out there in fanfic w...         1
# 1837  Chapter One: Goin' Back To Hogwarts"Are you su...         1
# 1838  Disclaimer: J.K. Rowling owns em.His FamilyCha...         1
# 1842  All things here belong to the beautiful mind o...         1
# 1846  Normal Pov(A/N: Story takes place in Harry Pot...         1
# 1847  (A/N: Rated M for mature content and language....         1
# 1848  Hey you guys, I'm back!I wasn't planning on wr...         1
# 1851  Chapter 1Beta Read by optimisticrealist72Thoug...         1
# 1852  "Now begin", Dumbledore's voice boomed over th...         1
# 1853  Hermione's POVShe grabbed another handful of r...         1
# 1855  Harry`s POVHarry Potter, boy who lived, chosen...         1
# 1857  A/N: Adopted from unwrittenlegacy. This will h...         1
# 1860  I do not own any of the characters. You may ho...         1
# 1861  Harry Potter, the Boy-Who-Lived, had always be...         1
# 1864  Author's Notes: In my own, happy little world,...         1
# 1865  Title: Fighting For TomorrowRating: TSummary: ...         1
# 1867  Authors note: Welcome to all the lovely reader...         1
# 1869  I do not own Harry Potter and I only write for...         1
#
# [723 rows x 3 columns]

# %%
# bella
# edward
# just
# said

# %%
from sklearn.feature_extraction import stop_words
['said', 'thee', 'ye'] + list(stop_words.ENGLISH_STOP_WORDS)
# Out:
# ['said',
#  'thee',
#  'ye',
#  'after',
#  'mostly',
#  'my',
#  'whereafter',
#  'been',
#  'sincere',
#  'see',
#  'con',
#  'and',
#  'elsewhere',
#  'every',
#  'however',
#  'others',
#  'couldnt',
#  'made',
#  'over',
#  'such',
#  'since',
#  'became',
#  'any',
#  'else',
#  'below',
#  'these',
#  'without',
#  'against',
#  'amoungst',
#  'still',
#  'whole',
#  'we',
#  'all',
#  'or',
#  'full',
#  'am',
#  'have',
#  'together',
#  'across',
#  'into',
#  'hence',
#  'sometimes',
#  'thereafter',
#  'must',
#  'first',
#  'moreover',
#  'only',
#  'alone',
#  'than',
#  'empty',
#  'they',
#  'yourselves',
#  'myself',
#  'few',
#  'out',
#  'cry',
#  'ten',
#  'done',
#  'throughout',
#  'twenty',
#  'were',
#  'whither',
#  'also',
#  'much',
#  'here',
#  'except',
#  'sometime',
#  'everything',
#  'move',
#  'as',
#  'this',
#  'un',
#  'fire',
#  'him',
#  'an',
#  'nevertheless',
#  'latter',
#  'take',
#  'us',
#  'etc',
#  'along',
#  'some',
#  'off',
#  'beside',
#  'get',
#  'whence',
#  'anyone',
#  'seemed',
#  'towards',
#  'further',
#  'thus',
#  'back',
#  'interest',
#  'never',
#  'he',
#  'ltd',
#  'part',
#  'yours',
#  'no',
#  'seem',
#  'perhaps',
#  'should',
#  'whenever',
#  'neither',
#  'under',
#  'behind',
#  'therein',
#  'already',
#  'do',
#  'itself',
#  'nobody',
#  'hundred',
#  'her',
#  'your',
#  'beyond',
#  'is',
#  'who',
#  'would',
#  'fill',
#  'it',
#  'may',
#  'their',
#  'fifteen',
#  'himself',
#  'those',
#  'give',
#  'hereafter',
#  'them',
#  'was',
#  'enough',
#  'front',
#  'mill',
#  'due',
#  'most',
#  'of',
#  'show',
#  'please',
#  'nothing',
#  'top',
#  'third',
#  'sixty',
#  'go',
#  'twelve',
#  'anywhere',
#  'other',
#  'so',
#  'herein',
#  'indeed',
#  'none',
#  'side',
#  'because',
#  'bottom',
#  'thick',
#  'thin',
#  'put',
#  'the',
#  'not',
#  'from',
#  'per',
#  'seems',
#  'three',
#  'somewhere',
#  'again',
#  'thru',
#  'within',
#  'whereupon',
#  'once',
#  'bill',
#  'whereby',
#  'beforehand',
#  'around',
#  'although',
#  'if',
#  'often',
#  'upon',
#  'nor',
#  'many',
#  'to',
#  'she',
#  'up',
#  'least',
#  'hers',
#  'that',
#  'while',
#  're',
#  'you',
#  'hereby',
#  'ever',
#  'same',
#  'whom',
#  'anyway',
#  'yourself',
#  'whatever',
#  'becoming',
#  'down',
#  'eight',
#  'can',
#  'his',
#  'one',
#  'about',
#  'former',
#  'four',
#  'ourselves',
#  'hasnt',
#  'via',
#  'which',
#  'be',
#  'co',
#  'thence',
#  'either',
#  'where',
#  'serious',
#  'always',
#  'too',
#  'toward',
#  'becomes',
#  'someone',
#  'call',
#  'themselves',
#  'what',
#  'even',
#  'everyone',
#  'keep',
#  'name',
#  'thereupon',
#  'wherein',
#  'formerly',
#  'through',
#  'somehow',
#  'afterwards',
#  'almost',
#  'eleven',
#  'two',
#  'yet',
#  'could',
#  'on',
#  'has',
#  'i',
#  'whether',
#  'meanwhile',
#  'nowhere',
#  'found',
#  'but',
#  'describe',
#  'wherever',
#  'fifty',
#  'amount',
#  'now',
#  'rather',
#  'might',
#  'very',
#  'mine',
#  'by',
#  'forty',
#  'whose',
#  'less',
#  'noone',
#  'own',
#  'before',
#  'being',
#  'detail',
#  'de',
#  'between',
#  'me',
#  'are',
#  'onto',
#  'something',
#  'among',
#  'namely',
#  'though',
#  'thereby',
#  'in',
#  'latterly',
#  'there',
#  'seeming',
#  'hereupon',
#  'why',
#  'until',
#  'above',
#  'next',
#  'had',
#  'then',
#  'whoever',
#  'nine',
#  'six',
#  'well',
#  'both',
#  'during',
#  'ours',
#  'ie',
#  'several',
#  'find',
#  'amongst',
#  'become',
#  'a',
#  'eg',
#  'at',
#  'otherwise',
#  'each',
#  'whereas',
#  'inc',
#  'five',
#  'anyhow',
#  'how',
#  'anything',
#  'herself',
#  'its',
#  'our',
#  'therefore',
#  'cannot',
#  'when',
#  'cant',
#  'last',
#  'with',
#  'system',
#  'everywhere',
#  'another',
#  'will',
#  'more',
#  'for',
#  'besides']
